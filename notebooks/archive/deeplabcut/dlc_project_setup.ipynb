# %%
from pathlib import Path

import deeplabcut

# %%
# Step 1: Create a new DeepLabCut project
# Only run this once to create the config and project directory.
PROJECT_ROOT = Path.cwd().resolve()

project_name = 'FishPoseProject'
experimenter = 'Lucas'

# Paths to the main .MOV files (skip before/after).
video_path = [
    str(PROJECT_ROOT / 'data/raw/archive/OLD/Old-1/old1.MOV'),
    str(PROJECT_ROOT / 'data/raw/archive/OLD/Old-2/old2.MOV'),
    str(PROJECT_ROOT / 'data/raw/archive/OLD/Old-3/old3.MOV'),
    str(PROJECT_ROOT / 'data/raw/archive/YOUNG/Young-1/young1.MOV'),
    str(PROJECT_ROOT / 'data/raw/archive/YOUNG/Young-2/young2.MOV'),
    str(PROJECT_ROOT / 'data/raw/archive/YOUNG/Young-3/young3.MOV'),
]

# Working directory for DeepLabCut projects.
working_directory = str(PROJECT_ROOT / 'DeepLabCut')

# Create project without copying videos.
deeplabcut.create_new_project(
    project_name,
    experimenter,
    video_path,
    working_directory,
    copy_videos=False,
)
